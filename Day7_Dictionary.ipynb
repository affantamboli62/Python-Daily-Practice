# %% [markdown]
# #Dictionary
# - {key:value}
#   - key: immutable elements(int,str,tuple)
# - Mutable
# - ordered(After o python 3.7)
# - Dictionaries are ordered .in python 3.65 and earlier , dict are unordered
# - Any changes we will do...we will be doing using **key**

# %%
d1={"name":"affan","age":22,"course":"DA"}
d1
# Out:
# {'name': 'affan', 'age': 22, 'course': 'DA'}

# %% [markdown]
# #Dict is Mutable

# %%
#changing element(value) in a dict

# %%
#L[index]=new value
#dictname[keyname]=new value
d1
# Out:
# {'name': 'affan', 'age': 22, 'course': 'DA'}

# %%
d1["name"]="tanmay"
d1
# Out:
# {'name': 'tanmay', 'age': 22, 'course': 'DA'}

# %%
d1
# Out:
# {'name': 'tanmay', 'age': 22, 'course': 'DA'}

# %%
#Adding new element in dict
#dictname[new_keyname]=new value
d1["id"]=101
d1
# Out:
# {'name': 'tanmay', 'age': 22, 'course': 'DA', 'id': 101}

# %%
d1["id"]=102
d1
# Out:
# {'name': 'tanmay', 'age': 22, 'course': 'DA', 'id': 102}

# %%
d1["ID"]=103
d1
# Out:
# {'name': 'tanmay', 'age': 22, 'course': 'DA', 'id': 102, 'ID': 103}

# %% [markdown]
# #Functions/Methods of dict
# - 1.get() : To get a value of mentioned key
# - 2.pop()
# - 3 popitem()
# - 4 keys() : key view
# - 5 values() : value veiw
# - 6 items() : key value pairs
# - 7 copy()
# - 8 clear()
# - 9 update({key:value}) :elements change

# %%
d1
# Out:
# {'name': 'tanmay', 'age': 22, 'course': 'DA', 'id': 102, 'ID': 103}

# %%
del d1["id"]

# %%
d1
# Out:
# {'name': 'tanmay', 'age': 22, 'course': 'DA', 'ID': 103}

# %%
d1.pop("name")
d1
# Out:
# {'age': 22, 'course': 'DA', 'ID': 103}

# %%
d1.popitem()
# Out:
# ('ID', 103)

# %%
d1
# Out:
# {'age': 22, 'course': 'DA'}

# %%
#city:"ratnagiri"
d1["city"]="Ratnagiri"
d1
# Out:
# {'age': 22, 'course': 'DA', 'city': 'Ratnagiri'}

# %%
d1.get("age")
# Out:
# 22

# %%
d1.keys()
# Out:
# dict_keys(['age', 'course', 'city'])

# %%
d1.values()
# Out:
# dict_values([22, 'DA', 'Ratnagiri'])

# %%
d1.items()
# Out:
# dict_items([('age', 22), ('course', 'DA'), ('city', 'Ratnagiri')])

# %%
d1.update({"name":"vijay"})
d1
# Out:
# {'age': 22, 'course': 'DA', 'city': 'Ratnagiri', 'name': 'vijay'}

# %%
d1.update({"name":"namra"})
d1
# Out:
# {'age': 22, 'course': 'DA', 'city': 'Ratnagiri', 'name': 'namra'}
