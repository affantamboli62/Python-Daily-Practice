# %%
import pandas as pd
big_martdata=pd.read_csv("/content/bigmart.csv")
big_martdata
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
big_martdata.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
big_martdata.describe
# Out:
# <bound method NDFrame.describe of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
big_martdata.shape
# Out:
# (8523, 12)

# %%
big_martdata.info
# Out:
# <bound method DataFrame.info of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
# group data with item_fat_content and establishment_year and calculate sum(item_outlet_sales)

# unique category in item_fat_content
big_martdata['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
big_martdata.replace({'LF':'Low Fat','low fat':'Low Fat','reg':'Regular'},inplace=True)

# %%
big_martdata
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
big_martdata['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
big_martdata["Outlet_Establishment_Year"].unique()
# Out:
# array([1999, 2009, 1998, 1987, 1985, 2002, 2007, 1997, 2004])

# %%
# group data with item_fat_content and establishment_year and calculate sum(item_outlet_sales)
big_martdata.groupby(['Item_Fat_Content','Outlet_Establishment_Year'])['Item_Outlet_Sales'].sum()
# Out:
# Item_Fat_Content  Outlet_Establishment_Year
# Low Fat           1985                         2.320602e+06
#                   1987                         1.410001e+06
#                   1997                         1.322210e+06
#                   1998                         1.246671e+05
#                   1999                         1.390523e+06
#                   2002                         1.293192e+06
#                   2004                         1.471696e+06
#                   2007                         1.369899e+06
#                   2009                         1.201305e+06
# Regular           1985                         1.313018e+06
#                   1987                         7.326630e+05
#                   1997                         7.961856e+05
#                   1998                         6.367312e+04
#                   1999                         7.934465e+05
#                   2002                         7.435335e+05
# ...

# %%
big_martdata.groupby('Outlet_Establishment_Year')['Item_Outlet_Sales'].min()
# Out:
# Outlet_Establishment_Year
# 1985     33.9558
# 1987     73.2380
# 1997    101.8674
# 1998     33.2900
# 1999    111.8544
# 2002     99.8700
# 2004    113.8518
# 2007    143.8128
# 2009     69.2432
# Name: Item_Outlet_Sales, dtype: float64

# %%
big_martdata.groupby(['Item_Fat_Content','Outlet_Establishment_Year'])['Item_Outlet_Sales'].max()
# Out:
# Item_Fat_Content  Outlet_Establishment_Year
# Low Fat           1985                         13086.9648
#                   1987                          9069.5276
#                   1997                          9779.9362
#                   1998                          1775.6886
#                   1999                          7646.0472
#                   2002                          8994.9580
#                   2004                          8479.6288
#                   2007                          9275.9256
#                   2009                          6768.5228
# Regular           1985                         12117.5600
#                   1987                         10256.6490
#                   1997                          7833.8028
#                   1998                          1575.2828
#                   1999                          6972.2576
#                   2002                          8851.1452
# ...

# %% [markdown]
# ###agg() ==> Aggregation of sum(),min(),max(),count()
# - syntax
#   - groupby().agg(["sum","min","max","count"])

# %%
big_martdata.groupby(['Outlet_Establishment_Year'])['Item_Outlet_Sales'].agg(["sum","min","max","count","mean"])
# Out:
#                                     sum       min         max  count  \
# Outlet_Establishment_Year
# 1985                       3.633620e+06   33.9558  13086.9648   1463
# 1987                       2.142664e+06   73.2380  10256.6490    932
# 1997                       2.118395e+06  101.8674   9779.9362    930
# 1998                       1.883402e+05   33.2900   1775.6886    555
# 1999                       2.183970e+06  111.8544   7646.0472    930
# 2002                       2.036725e+06   99.8700   8994.9580    929
# 2004                       2.268123e+06  113.8518   8479.6288    930
# 2007                       2.167465e+06  143.8128   9664.7528    926
# 2009                       1.851823e+06   69.2432   6768.5228    928
#
#                                   mean
# Outlet_Establishment_Year
# 1985                       2483.677474
# 1987                       2298.995256
# 1997                       2277.844267
# 1998                        339.351662
# ...

# %% [markdown]
# ###check data types of all columns

# %%
big_martdata
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
big_martdata.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %% [markdown]
# #To change Data Type
# - syntax
#   - pd.to_datetime(bigmart_data["Outlet_Establishment_Year"])

# %% [markdown]
# ##To round the particular values

# %%
big_martdata["Item_Visibility"]=big_martdata["Item_Visibility"].round(3)
big_martdata
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat            0.016
# 1              DRC01        5.920          Regular            0.019
# 2              FDN15       17.500          Low Fat            0.017
# 3              FDX07       19.200          Regular            0.000
# 4              NCD19        8.930          Low Fat            0.000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat            0.057
# 8519           FDS36        8.380          Regular            0.047
# 8520           NCJ29       10.600          Low Fat            0.035
# 8521           FDN46        7.210          Regular            0.145
# 8522           DRG01       14.800          Low Fat            0.045
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ##To ignore Future warnings
# - step1 : import warnings
# - step2 : print(dir(warnings))
# - step3 : warnings.filterwarnings("ignore")
# - step4 if need : To perticular warnings ("ignore",category="Userwarnings/Depricationwarnings)

# %% [markdown]
# #set_option to all datasets/column you see 2 decimals
# - syntax
#   - pd.set_option('display.float_format','{:.2f}'.format)

# %%
pd.set_option('display.float_format','{:.2f}'.format)

# %%
big_martdata
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat             0.02
# 1              DRC01         5.92          Regular             0.02
# 2              FDN15        17.50          Low Fat             0.02
# 3              FDX07        19.20          Regular             0.00
# 4              NCD19         8.93          Low Fat             0.00
# ...              ...          ...              ...              ...
# 8518           FDF22         6.87          Low Fat             0.06
# 8519           FDS36         8.38          Regular             0.05
# 8520           NCJ29        10.60          Low Fat             0.04
# 8521           FDN46         7.21          Regular             0.14
# 8522           DRG01        14.80          Low Fat             0.04
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy    249.81            OUT049
# ...

# %%
data=pd.DataFrame({
    "Date":["2025-01-01","2025-02-02","2025-03-03"]
})

# %%
data
# Out:
#          Date
# 0  2025-01-01
# 1  2025-02-02
# 2  2025-03-03

# %%
data.dtypes
# Out:
# Date    object
# dtype: object

# %%
data['Date']=pd.to_datetime(data["Date"])
# Out:
# /tmp/ipython-input-2078928053.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date']=pd.to_datetime(data["Date"])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# /tmp/ipython-input-2078928053.py in <cell line: 0>()
# ----> 1 data['Date']=pd.to_datetime(data["Date"])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
# ...

# %%
data.dtypes
# Out:
# Date    object
# dtype: object

# %%
import datetime
from datetime import datetime as dt

# %%
print(dir(dt))
# Out:
# ['__add__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__rsub__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', 'astimezone', 'combine', 'ctime', 'date', 'day', 'dst', 'fold', 'fromisocalendar', 'fromisoformat', 'fromordinal', 'fromtimestamp', 'hour', 'isocalendar', 'isoformat', 'isoweekday', 'max', 'microsecond', 'min', 'minute', 'month', 'now', 'replace', 'resolution', 'second', 'strftime', 'strptime', 'time', 'timestamp', 'timetuple', 'timetz', 'today', 'toordinal', 'tzinfo', 'tzname', 'utcfromtimestamp', 'utcnow', 'utcoffset', 'utctimetuple', 'weekday', 'year']

# %%
# This not work becoz data type is object
data['Date']=data['Date'].dt.strftime('%d%m%Y')
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4082398396.py in <cell line: 0>()
#       1 # This not work becoz data type is object
# ----> 2 data['Date']=data['Date'].dt.strftime('%d%m%Y')
#       3 data
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
# ...
