# %% [markdown]
# # string
# - string is ordered
# - "s",'s',"""s"""
# - str()
# - immutable
# - stored==>array format
# - indexing=0,1,2,3...

# %% [markdown]
# #String Functions
# - 1.upper()
# - 2.lower()
# - 3.title()
# - 4.capitalize()
# - 5.strip() remove starting and ending spaces
# - 6.lstrip()
# - 7.rstrip()
# - 8.count() mentioned char/word count
# - 9.find() if character is not present it shows -1
# - 10.index() if character is not present it shows error
# - 11.len()
# - 12.split() bydefault space
# - 13.rsplit() it works as split fun
# - 14.replace()

# %%
#syntax : varname.fnname(parameters)
s1="i am learning python"
s1.upper()
# Out:
# 'I AM LEARNING PYTHON'

# %%
s1="i am learning python"
s1.lower()
# Out:
# 'i am learning python'

# %%
s1="i am learning python"
s1.title()
# Out:
# 'I Am Learning Python'

# %%
s1="i am learning python"
s1.capitalize()
# Out:
# 'I am learning python'

# %%
s2="        data     science "

# %%
s2.strip()
# Out:
# 'data     science'

# %%
s2.lstrip()
# Out:
# 'data     science '

# %%
s2.rstrip()
# Out:
# '        data     science'

# %%
s1
# Out:
# 'i am learning python'

# %%
s1.count("I")
# Out:
# 0

# %%
s1.count("python")
# Out:
# 1

# %%
s1.count("n")
# Out:
# 3

# %%
s1.find("i")
# Out:
# 0

# %%
s1.find("a")
# Out:
# 2

# %%
s1.find("p")
# Out:
# 14

# %%
s1.find("python")
# Out:
# 14

# %%
s1.index("i")
# Out:
# 0

# %%
s1.index("n")
# Out:
# 9

# %%
len(s1) # it is inbuilt fun we can't use dot(.)
# Out:
# 20

# %%
sum([4,2]) # it is inbuild func
# Out:
# 6

# %%
s1
# Out:
# 'i am learning python'

# %%
s1.split()
# Out:
# ['i', 'am', 'learning', 'python']

# %%
s1.split("l")
# Out:
# ['i am ', 'earning python']

# %%
s3=" a,b,c "

# %%
s3.split()
# Out:
# ['a,b,c']

# %%
s3.split(",")
# Out:
# [' a', 'b', 'c ']

# %%
s3.rsplit()
# Out:
# ['a,b,c']

# %%
s3.rsplit(",",1)
# Out:
# [' a,b', 'c ']

# %%
s1
# Out:
# 'i am learning python'

# %%
s1.replace("python","data analysis")
# Out:
# 'i am learning data analysis'

# %%
s1
# Out:
# 'i am learning python'

# %% [markdown]
# #Boolean String Function : Result shows TRUE AND FALSE

# %% [markdown]
# ###Boolean String Functions
# - 1.isalpha() : only char
# - 2.isalnum() : not space
# - 3.isdigit() : only num (not space)
# - 4.islower() : only char
# - 5.isupper() : only char
# - 6.isspace() : only check spaces
# - 7.isnumeric() : only check numeric data (not space & char")
# - 8.startswith()
# - 9.endswith()

# %%
s1="123"
s2="data1123"
s3="data"
s4=" "
s5=" data123 "

# %%
s1.isalpha()
s2.isalpha()
s3.isalpha()
s4.isalpha()
s5.isalpha()
#multiple cursors : ctrl + alt
# Out:
# False

# %%
print(s1.isalpha())
print(s2.isalpha())
print(s3.isalpha())
print(s4.isalpha())
print(s5.isalpha())
# Out:
# False
# False
# True
# False
# False

# %%
print(s1.isalnum())
print(s2.isalnum())
print(s3.isalnum())
print(s4.isalnum())
print(s5.isalnum())
# Out:
# True
# True
# True
# False
# False

# %%
print(s1.isdigit())
print(s2.isdigit())
print(s3.isdigit())
print(s4.isdigit())
print(s5.isdigit())
# Out:
# True
# False
# False
# False
# False

# %%
print(s1.islower())
print(s2.islower())
print(s3.islower())
print(s4.islower())
print(s5.islower())
# Out:
# False
# True
# True
# False
# True

# %%
print(s1.isupper())
print(s2.isupper())
print(s3.isupper())
print(s4.isupper())
print(s5.isupper())
# Out:
# False
# False
# False
# False
# False

# %%
print(s1.isspace())
print(s2.isspace())
print(s3.isspace())
print(s4.isspace())
print(s5.isspace())
# Out:
# False
# False
# False
# True
# False

# %%
print(s1.isnumeric())
print(s2.isnumeric())
print(s3.isnumeric())
print(s4.isnumeric())
print(s5.isnumeric())
# Out:
# True
# False
# False
# False
# False

# %%
s1.startswith("1")
# Out:
# True

# %%
s1="i am learning data anlytics"
s1.startswith("I")
# Out:
# False

# %%
s1.endswith("anlytics")
# Out:
# True

# %%
s1.endswith("s")
# Out:
# True

# %%
# ask yhe user to enter a password then check validity based on rules
# rules : 1.len(8) , 2.lowercase ,only alphabets
password=str(input("enter the password:"))
if len(password)==8 and password.islower()==True and password.isalpha():
  print("correct password")
else :
  print("wrong password")
# Out:
# enter the password:aaaaaaaa
# correct password

# %% [markdown]
# #String Operators

# %% [markdown]
# 1.  (+) = use for concatenation

# %%
"data"+" "+"science"
# Out:
# 'data science'

# %% [markdown]
# 2. (*) : use for repetation

# %%
"data"*4
# Out:
# 'datadatadatadata'

# %% [markdown]
# 3. (in) :check membership

# %%
s="python"
"p" in s
# Out:
# True

# %% [markdown]
# 4. (not in) : check membership

# %%
s="python"
"c" not in s
# Out:
# True

# %% [markdown]
# # String indexing and slicing

# %%
# slicing==> extracting part of the string or text using index

# %% [markdown]
# #### syntax: stringname[index]
#             -stringname[stringindex:stop index(one extra position) :step value]
#             -bydefault : step value = 1

# %%
s1="I am learning python"
s1[0]
# Out:
# 'I'

# %%
s1[14:21] # positive indexing
# Out:
# 'python'

# %% [markdown]
# ####Indexing Type :
#        -1.positive : left to right(0,1,2,...)
#        -2.negative : right to left(-1,-2,-3,...)

# %%
s1[-6]
# Out:
# 'p'

# %%
s1[-6:]
# Out:
# 'python'

# %%
s1[-2:]
# Out:
# 'on'

# %%
#extract "learning" word from string
#positive
#first find index of learning
s1.find("learning")
# Out:
# 5

# %%
#positive
s1[5:13]
# Out:
# 'learning'

# %%
#negative
s1[-15:-7]
# Out:
# 'learning'

# %% [markdown]
# ####Reverse string

# %%
s1
# Out:
# 'I am learning python'

# %%
s1[::-1]
# Out:
# 'nohtyp gninrael ma I'

# %%
#reverse "python" word : nohtyp
#reverse string using +ve indexing
s1[19:13:-1] #positive
# Out:
# 'nohtyp'

# %%
#reverse "python" word : nohtyp
#reverse string using -ve indexing
s1[-1:-7:-1] #negative
# Out:
# 'nohtyp'

# %%
#Q1 find extension
filepath1="desktop/python.py"
filepath1.find(".py")
# Out:
# 14

# %%
#positive
filepath1[15:17]
# Out:
# 'py'

# %%
#negative
filepath1[-2:]
# Out:
# 'py'

# %%
#Q2 extract only numeric data
productcode="PRD_2025_xyx"
#+ve
productcode[4:8]
# Out:
# '2025'

# %%
#Q2 extract only numeric data
productcode="PRD_2025_xyx"
#-ve
productcode[-8:-4]
# Out:
# '2025'

# %%
#Q3 reverse string
word="nayan"
word[::-1]
# Out:
# 'nayan'

# %%
#conversion datatype
#example
age=input("enter your age :")
msg="This is your age :"+str(age)
print(msg)
# Out:
# enter your age :22
# This is your age :22
