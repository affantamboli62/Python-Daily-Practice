# %% [markdown]
# #TOkens

# %% [markdown]
# # DATA TYPES

# %% [markdown]
# - 1.Numbers
#   -int()
#   -float()
#   -complex()
#
# - 2.string : Text
#   -str()
#
# - 3.List : multiple elements (int,float,string,tuple,set,list,dict)
#   -list() : [1,2,2.5,3,"affan"]
#
# - 4.Tuple : multiple elements (int,float,string,tuple,set,list,dict)
#   -tuple() : (1,2,3,2.5)
#
# - 5.Dictonary : key : value
#   -dict() :{"name" : "affan"}
#
# - 6.set() : {1,2,3,4,5}
#   -frozenset()
#
# - 7.Boolean :
#   -bool() : True and False

# %% [markdown]
# #Mutable and Immutable

# %% [markdown]
# - #### 1.Mutable : We can change,add,remove elements.
#       -LDS : list() ,dict() ,set()
#
# - #### 2.Immutable : We can't change,add,remove elements.
#       -STN : str() ,tuple() ,number(int,float)

# %%
l1=[1,2,3,4]

# %%
l1[0]=10 #change

# %%
print(l1)
# Out:
# [10, 2, 3, 4]

# %%
l1.append(5)

# %%
print(l1)
# Out:
# [10, 2, 3, 4, 5]

# %%
a=20
b=90
add=a+b
sub=a-b
print(add)
print(sub)
# Out:
# 110
# -70

# %%
l1.extend(["affan",12])

# %%
print(l1)
# Out:
# [10, 2, 3, 4, 5, 'affan', 12, 'affan', 12, 'affan', 12]

# %%
s1="i am learning excel"

# %%
s1.replace("excel","python")
# Out:
# 'i am learning python'

# %%
print(s1)
# Out:
# i am learning excel

# %% [markdown]
# #Getting Data Type

# %%
a=20
b=23.7
l=[1,2,3]
t=(1,2,3)
s="python"
bo=True
s1={1,2,4,5}
d={"name":"affan"}

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(s1)
# Out:
# set

# %%
type(d)
# Out:
# dict

# %%
type(bo)
# Out:
# bool

# %%
type(s)
# Out:
# str

# %%
type("python")
# Out:
# str

# %%
type(t)
# Out:
# tuple

# %%
print(a)
print(b)
# Out:
# 20
# 23.7

# %%
print(a,b,s,s1,t)
# Out:
# 20 23.7 python {1, 2, 4, 5} (1, 2, 3)

# %%
print(a,
      b,
      t,
      s1)
# Out:
# 20 23.7 (1, 2, 3) {1, 2, 4, 5}

# %%
a=10
b=20
c=a+b
print("Addition is :",c)
c=a-b
print("Differnce is :",c)
# Out:
# Addition is : 30
# Differnce is : -10

# %% [markdown]
# #Getting Result from the input

# %%
a=90 #input inside the code
# syntax : var=datatype(input("message"))
name=str(input("Enter your Name :")) #user input
surname=input("Enter your Surname :") #by default datatype :str
marks1=float(input("Enter your marks1 :"))
marks2=int(input("Enter your marks2 :"))
print("full name :",name+" "+surname)
print("marks1 :",marks1)
print("marks2 :",marks2)
result=marks1+marks2
print("result:",result)
# Out:
# Enter your Name :AFFAN
# Enter your Surname :TAMBOLI
# Enter your marks1 :76
# Enter your marks2 :87
# full name : AFFAN TAMBOLI
# marks1 : 76.0
# marks2 : 87
# result: 163.0

# %%
#find out area of rectangle
#formula=length*breadth
length=4.5
breadth=3.2
area_of_rectangle=length*breadth
print("Area of Rectangle :",area_of_rectangle)
# Out:
# Area of Rectangle : 14.4

# %% [markdown]
# #Getting User Side

# %%
#find out area of rectangle
#formula=length*breadth
length=float(input("Length of Rectangle :"))
breadth=float(input("Breadth of Rectangle :"))
area_of_rectangle=length*breadth
print("Area of Rectangle :",area_of_rectangle)
# Out:
# Length of Rectangle :4.5
# Breadth of Rectangle :3.2
# Area of Rectangle : 14.4

# %%
#Find perimeter of rectangle
#formula= perimeter=2*(length+breadth)
length=float(input("Length of Rectangle :"))
breadth=float(input("Breadth of Rectangle :"))
perimeter_of_rectangle=2*(length+breadth)
print("Perimeter of Rectangle :",perimeter_of_rectangle)
# Out:
# Length of Rectangle :4.5
# Breadth of Rectangle :3.2
# Perimeter of Rectangle : 15.4

# %%
#Find area of circle
#formula=pie r(square)
pie=float(3.14)
radius=3
area_of_circle=3.14*(3*3)
print("Area of circle :",area_of_circle)
# Out:
# Area of circle : 28.26

# %%
#getting user side
#Find area of circle
#formula=pie r(square)
pi=float(input("Enter the pi value :"))
radius=float(input("Enter the radius :"))
area_of_circle=pi*(radius*radius)
print("Area of circle :",area_of_circle)
# Out:
# Enter the pi value :3.14
# Enter the radius :4.5
# Area of circle : 63.585

# %%
# Arithmetic Operations
a=20
b=10
c=a+b
print("ADDITION IS :",c)
c=a-b
print("SUBSTRACTION IS :",c)
c=a*b
print("MULTIPLICATION IS :",c)
c=a/b
print("DIVISION IS :",c)
# Out:
# ADDITION IS : 30
# SUBSTRACTION IS : 10
# MULTIPLICATION IS : 200
# DIVISION IS : 2.0

# %% [markdown]
# #MODULE AND PACKAGES IN PYTHON

# %%
#math calculation
#math==>staticstics==>library
#package/library==>module==>functions
#to call any built in modules/packages/libraries

# %%
import math

# %%
#dir:directories(folder)
math.pi
# Out:
# 3.141592653589793

# %%
#getting user side
#Find area of circle
#formula=pie r(square)
radius=float(input("Enter the radius :"))
area_of_circle=math.pi*(radius*radius)
print("Area of circle :",area_of_circle)
# Out:
# Enter the radius :4.5
# Area of circle : 63.61725123519331

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %% [markdown]
# #cell mapdown==>select cell==>alt+m==>1,2,3,4,5,6

# %% [markdown]
# #SQUARE ROOT

# %%
#CALCULATE SQUARE ROOT
2025**0.5
# Out:
# 45.0

# %%
math.pow(2025,0.5)
# Out:
# 45.0

# %%
math.sqrt(2025)
# Out:
# 45.0

# %%
import datetime #package

# %%
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', 'UTC', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
import statistics as st

# %%
#Avearge of list
l=[23,56,98,65,32]
st.mean(l)
# Out:
# 54.8

# %%
import math

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
import datetime as dt

# %%
#from statistics import math
import math

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %% [markdown]
# #DATETIME MODULE FROM DATETIME PACKAGE

# %%
import datetime #package

# %%
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', 'UTC', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
from datetime import datetime as dt #module

# %%
print(dir(dt))
# Out:
# ['__add__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__rsub__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', 'astimezone', 'combine', 'ctime', 'date', 'day', 'dst', 'fold', 'fromisocalendar', 'fromisoformat', 'fromordinal', 'fromtimestamp', 'hour', 'isocalendar', 'isoformat', 'isoweekday', 'max', 'microsecond', 'min', 'minute', 'month', 'now', 'replace', 'resolution', 'second', 'strftime', 'strptime', 'time', 'timestamp', 'timetuple', 'timetz', 'today', 'toordinal', 'tzinfo', 'tzname', 'utcfromtimestamp', 'utcnow', 'utcoffset', 'utctimetuple', 'weekday', 'year']

# %%
#from statistics import math
current_date_time=dt.today()
print(current_date_time)
# Out:
# 2025-09-08 08:10:20.543409

# %%
dt.now()
# Out:
# datetime.datetime(2025, 9, 8, 8, 10, 42, 542400)

# %%
#format date and time==>strftime("format")==>date_format()
#day-month-year |H:M:S
current_date_time.strftime("%d-%m-%y | %H:%M:%S")
# Out:
# '08-09-25 | 08:10:20'

# %%
dt.today().year
# Out:
# 2025

# %%
current_date_time.year
# Out:
# 2025

# %%
current_date_time.strftime("%D-%M-%Y | %H:%M:%S")
# Out:
# '09/08/25-10-2025 | 08:10:20'

# %%
current_date_time.strftime("%a-%B-%Y | %H:%M%S")
# Out:
# 'Mon-September-2025 | 08:1020'
