# %% [markdown]
# #Types of Operators

# %% [markdown]
# - 1.Arithmetic operators : +,-,/,*,%(reminder),**(power),//(quotient)
# - 2.Assignment Operators : =,+=,-=,*=,%=,//=
# - 3.Logical Operators : and,or,not
# - 4.Membership operators : in,not in
# - 5.comparision operator : ==,!=,>=,<=,>,<
# - 6.identity operators : is,is not

# %%
# Arithmetic Operators
20%40
# Out:
# 20

# %%
40%20
# Out:
# 0

# %%
40//20
# Out:
# 2

# %%
# Assignment operators
x=5

# %%
x=x+5

# %%
x
# Out:
# 10

# %%
x+=5
x
# Out:
# 15

# %%
x-=10
x
# Out:
# 5

# %%
x*=3
x
# Out:
# 15

# %%
x%=5
x
# Out:
# 0

# %% [markdown]
# - 3.Logical Operators
#   - and
#   - or
#   - not

# %% [markdown]
# - 4.Membership operators
#   - in
#   - not in

# %% [markdown]
# - 5.Comparision Operators : ==,!=,>=,<=,>,<

# %% [markdown]
# - 6.identity operators
#   - is
#   - is not

# %% [markdown]
# - 7.Bitwise Operators
#   - &
#   - |

# %%
10 & 5
# Out:
# 0

# %%
10 | 5
# Out:
# 15

# %% [markdown]
# ### Binary Conversion
# - 32 16 8 4 2 1
# - Binary : 4 digit or 8 digit
# - 10 : 1 0 1 0
# - 16 : 0 0 0 1 0 0 0 0
# - 5  : 0 1 0 1
# - 10&5 : 0000
# - 10|5 : 1111

# %% [markdown]
# # Left-Right Associativity

# %%
print(5*2//3)
# Out:
# 3

# %%
10//3
# Out:
# 3

# %%
print(5*(2//3))
# Out:
# 0

# %% [markdown]
# # Right-Left Associativity
# - **(power/exponent)

# %%
print(2**3**2)
# Out:
# 512

# %%
2**3
# Out:
# 8

# %%
8**2
# Out:
# 64

# %%
3**2
# Out:
# 9

# %%
2**9
# Out:
# 512

# %%
print((2**3)**2)
# Out:
# 64

# %% [markdown]
# # eval() function
# - python inbuilt() function

# %%
name=eval(input("enter your name :"))
surname=eval(input("enter your surname :"))
name+surname
# Out:
# enter your name :"affan"
# enter your surname :"tamboli"
# 'affantamboli'

# %%
name=eval(input("enter your name :"))
surname=eval(input("enter your surname :"))
name+surname
# Out:
# enter your name :affan
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1453763124.py in <cell line: 0>()
# ----> 1 name=eval(input("enter your name :"))
#       2 surname=eval(input("enter your surname :"))
#       3 name+surname
#
# <string> in <module>
#
# NameError: name 'affan' is not defined

# %%
name=eval(input("enter your name :"))
surname=eval(input("enter your surname :"))
name+surname
# Out:
# enter your name :(1,2,3)
# enter your surname :(4,5,6)
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# ###Using eval() fn solving maths expressions

# %%
x=1
y=4
z=10
expression=2*x+4*y+z*z*3
expression
# Out:
# 318

# %%
expression=input("Enter your expression :")
x=1
y=4
z=10
sol=eval(expression)
sol
# Out:
# Enter your expression :2*x+4*y+z*z*3
# 318
